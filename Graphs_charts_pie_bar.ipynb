# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from scipy.stats import poisson

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
# plt.plot(x,y)
plt.scatter(x,y)
# plt.grid()
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

# %%
x = np.array(["A", 2, "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

# plt.barh(x,y)
plt.barh(x, y, color = "yellow")
# Out:
# <BarContainer object of 4 artists>

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x20f13f48920>,
#   <matplotlib.patches.Wedge at 0x20f11cc3cb0>,
#   <matplotlib.patches.Wedge at 0x20f13f4b860>,
#   <matplotlib.patches.Wedge at 0x20f13f4bf50>],
#  [Text(0.4993895680663529, 0.9801071672559597, ''),
#   Text(-1.086457168210212, 0.17207795223283895, ''),
#   Text(-0.172077952232839, -1.086457168210212, ''),
#   Text(0.9801071672559598, -0.4993895680663526, '')])

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
# Out:
# ([<matplotlib.patches.Wedge at 0x20f153cd1c0>,
#   <matplotlib.patches.Wedge at 0x20f153a74d0>,
#   <matplotlib.patches.Wedge at 0x20f153cd8e0>,
#   <matplotlib.patches.Wedge at 0x20f153cdca0>],
#  [Text(0.4993895680663529, 0.9801071672559597, 'Apples'),
#   Text(-1.086457168210212, 0.17207795223283895, 'Bananas'),
#   Text(-0.172077952232839, -1.086457168210212, 'Cherries'),
#   Text(0.9801071672559598, -0.4993895680663526, 'Dates')])
